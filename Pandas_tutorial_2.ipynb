# %%
import numpy as np
import pandas as pd

# %%
inventaris = pd.read_csv('toko_inventaris.csv', delimiter = ',',names = ['barang','merek','jumlah'])

# %%
inventaris
# Out:
#    barang                       merek  jumlah
# 0   rokok                       Patra      50
# 1   rokok  Gudang Garam International      20
# 2   rokok               Djarum Coklat      20
# 3     mie                     Indomie      35
# 4     mie                      Sarimi      20
# 5     mie                      Popmie      30
# 6     mie                 Mie Sedaaap      32
# 7   beras                   Rojo Lele      20
# 8   beras                Pandan Wangi      30
# 9    buah                        Apel      15
# 10   buah                      Pisang      17

# %%
inventaris.barang.count()
# Out:
# 11

# %%
inventaris.jumlah.sum()
# Out:
# 289

# %%
inventaris.jumlah.max()
# Out:
# 50

# %%
inventaris.jumlah.min()
# Out:
# 15

# %%
inventaris.jumlah.mean()
# Out:
# 26.272727272727273

# %%
inventaris.jumlah.median()
# Out:
# 20.0

# %%
inventaris.groupby('barang').mean()
# Out:
#         jumlah
# barang
# beras    25.00
# buah     16.00
# mie      29.25
# rokok    30.00

# %%
inventaris.groupby('barang').mean()[['jumlah']]
# Out:
#         jumlah
# barang
# beras    25.00
# buah     16.00
# mie      29.25
# rokok    30.00

# %%
article_read = pd.read_csv('pandas_tutorial_read.csv', delimiter=';', names = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic'])

# %%
article_read
# Out:
#               my_datetime event    country     user_id   source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 5     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 6     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 7     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 8     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 9     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 10    2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# ...

# %%
article_read.groupby('source').count()[['user_id']]
# Out:
#          user_id
# source
# AdWords      500
# Reddit       949
# SEO          346

# %%
article_read[article_read.country == 'country_2'].groupby(['source','topic']).count()[['user_id']]
# Out:
#                        user_id
# source  topic
# AdWords Africa               3
#         Asia                31
#         Australia            6
#         Europe              46
#         North America       11
#         South America       14
# Reddit  Africa              24
#         Asia               139
#         Australia           18
#         Europe              29
#         North America       27
#         South America       26
# SEO     Africa               7
#         Asia                 9
#         Australia           10
#         Europe               4
#         North America       42
#         South America       16
